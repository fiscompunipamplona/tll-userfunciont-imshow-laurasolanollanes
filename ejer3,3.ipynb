# %%
from google.colab import files
files.upload()
from google.colab import drive
drive.mount('/content/gdrive/')
import sys
# Out:
#      <input type="file" id="files-59171237-c6a9-4ce1-8ea4-2b5d234ff959" name="files[]" multiple disabled />
#      <output id="result-59171237-c6a9-4ce1-8ea4-2b5d234ff959">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving stm.txt to stm.txt
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
from pylab import plot, imshow, show, xlabel, ylabel
from numpy import loadtxt

data=loadtxt("stm.txt",float)

#imshow(data,origin="lower")
xlabel("Interferencia en x cm ")
ylabel("interferencia en y cm")
imshow(data, origin="lower", extent=[0,100,0,100])
show()
